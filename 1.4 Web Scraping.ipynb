# %% [markdown]
# # Importing Libraries and Driver

# %%
import pandas as pd
import time
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
import matplotlib.pyplot as plt
import os
import logging
import requests
import bs4
from bs4 import BeautifulSoup

# %%
# Setting up Chrome Options
chrome_options = Options()
chrome_options.add_argument("--headless")  # to ensure GUI is off
chrome_options.add_argument("--no-sandbox")

# %%
# Installing and Initializing Chrome Driver Manager
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

# %% [markdown]
# # Scraping and Parsing Wiki History and Politics Contents

# %%
# Getting webpage content
headers = {'User-Agent': 'MGWikiBot/1.0 (MGsbbz@hotmail.com)'}
page = requests.get('https://en.wikipedia.org/wiki/Key_events_of_the_20th_century', headers=headers)

# %%
# Parsing webpage content
soup = BeautifulSoup(page.text, 'html.parser')
print(soup.title)
# Out:
# <title>Key events of the 20th century - Wikipedia</title>

# %%
# Creating text object to store URL text
text = soup.get_text()
text = text.encode('utf-8')

# %% [markdown]
# # Saving Contents as Text File

# %%
# Saving the file in the working directory
with open('20th_century_article.txt', 'wb') as f:
    f.write(text)
